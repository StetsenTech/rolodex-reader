# %% [markdown]
# ## Processing Input

# %%
import re
import phonenumbers

# %% [markdown]
# ### Regex Expressions
# Based on prompt, there are only 3 valid entry formats that are acceptable
#
# Create regex expressions that match the following:
# ```
# Lastname, Firstname, (703)-742-0996, Blue, 10013
# Firstname Lastname, Red, 11237, 703 955 0373
# Firstname, Lastname, 10013, 646 111 0101, Green
# ```

# %%
valid_one = re.compile((
    r'(?P<last>[A-z]+),\s(?P<first>[A-z. ]+),\s'
    r'(?P<phone>\([0-9]{3}\)-[0-9]{3}-[0-9]{4}),\s'
    r'(?P<color>[A-z ]+),\s(?P<zip>[0-9]{5})'
))
valid_two = re.compile((
    r'(?P<first>[A-z. ]+)\s(?P<last>[A-z]+),\s'
    r'(?P<color>[A-z ]+),\s(?P<zip>[0-9]{5}),\s'
    r'(?P<phone>[0-9]{3}\s[0-9]{3}\s[0-9]{4})'
))
valid_three = re.compile((
    r'(?P<first>[A-z. ]+),\s(?P<last>[A-z]+),\s'
    r'(?P<zip>[0-9]{5}),\s(?P<phone>[0-9]{3}\s[0-9]{3}\s[0-9]{4}),\s'
    r'(?P<color>[A-z ]+)'
))

# %% [markdown]
# ### Read input file
# A data file (`data.in`) was supplied that has 64 entries. Input is a list of string items.

# %%
with open("data.in") as input_file:
    entries = input_file.read().splitlines() # Makes sure new lines are striped

# %% [markdown]
# ### Process Entries
# For every entry in the list, check to see if the entry matches of the the regex validators.
# If the entry matches, parse the string into a dictionary for further processing.
# If not, add the index to a list that tracks which entries are invalid.

# %%
valid_entries = []
errors = []

for i, entry in enumerate(entries):
    # Check to see if entry is valid 
    if valid_one.match(entry):
        entry_match = valid_one.match(entry)
    elif valid_two.match(entry):
        entry_match = valid_two.match(entry)
    elif valid_three.match(entry):
        entry_match = valid_three.match(entry)
    else:
        errors.append(i)
        continue

    phone = phonenumbers.parse(entry_match.group("phone"), "US")
    
    
    entry_dict = {
        "first_name": entry_match.group("first"),
        "last_name": entry_match.group("last"),
        "phone_number": phonenumbers.format_number(phone, "{}-{}-{}"),
        "color": entry_match.group("color"),
        "zipcode": entry_match.group("zip")
    }

    valid_entries.append(entry_dict)

# %% [markdown]
# Debugging to ensure processing went properly. 17 of the entries appears to be an invalid format based on the 3 examples.

# %%
print "Number of entries:", len(entries)
print "Number of valid entries:", len(valid_entries)
print "Number of Erroneous entries:", len(errors)
print "Erroneous entries:", errors
# Out:
# Number of entries: 64
# Number of valid entries: 47
# Number of Erroneous entries: 17
# Erroneous entries: [0, 5, 7, 15, 16, 29, 37, 38, 41, 43, 44, 45, 47, 48, 56, 57, 62]

# %% [markdown]
# ## Serialize Data

# %%
from marshmallow import Schema, fields, post_dump, pprint

# %% [markdown]
# Create schemata that will make sure inputs are the correct type

# %%
class EntrySchema(Schema):
    """Schema for rolodex entry"""
    first_name = fields.String(required=True, dump_to="firstname")
    last_name = fields.String(required=True, dump_to="lastname")
    phone_number = fields.String(required=True, dump_to="phonenumber")
    zipcode = fields.String(required=True)
    color = fields.String(required=True)

# %%
class OutputSchema(Schema):
    """Schema for output"""
    entries = fields.Nested(EntrySchema, many=True, required=True, default=[]) # Items in list match the EntrySchema
    errors = fields.List(fields.Integer(), default=[])

# %%
output_schema = OutputSchema()

# %%
data = {"entries": valid_entries, "errors": errors}

# %%
output_dict = output_schema.dump(data).data
pprint(output_dict)
# Out:
# {u'entries': [{u'color': u'aqua marine',
#                u'firstname': u'Ria',
#                u'lastname': u'Tillotson',
#                u'phonenumber': u'196-910-5548',
#                u'zipcode': u'97671'},
#               {u'color': u'blue',
#                u'firstname': u'Annalee',
#                u'lastname': u'Loftis',
#                u'phonenumber': u'905-329-2054',
#                u'zipcode': u'97296'},
#               {u'color': u'gray',
#                u'firstname': u'James',
#                u'lastname': u'Johnston',
#                u'phonenumber': u'628-102-3672',
#                u'zipcode': u'38410'},
#               {u'color': u'yellow',
#                u'firstname': u'Quinton',
#                u'lastname': u'Liptak',
#                u'phonenumber': u'653-889-7235',
#                u'zipcode': u'70703'},
#               {u'color': u'aqua marine',
#                u'firstname': u'George',
#                u'lastname': u'Won',
#                u'phonenumber': u'488-084-5794',
#                u'zipcode': u'97148'},
#               {u'color': u'pink',
#                u'firstname': u'Gladis',
#                u'lastname': u'Tubb',
#                u'phonenumber': u'454-934-6454',
#                u'zipcode': u'73149'},
#               {u'color': u'pink',
#                u'firstname': u'Aura',
#                u'lastname': u'Eilers',
#                u'phonenumber': u'489-634-9504',
#                u'zipcode': u'39358'},
#               {u'color': u'red',
#                u'firstname': u'Blair',
#                u'lastname': u'Clary',
#                u'phonenumber': u'463-118-2451',
#                u'zipcode': u'07256'},
#               {u'color': u'pink',
#                u'firstname': u'Robert',
#                u'lastname': u'Hood',
#                u'phonenumber': u'054-813-6030',
#                u'zipcode': u'47784'},
#               {u'color': u'aqua marine',
#                u'firstname': u'Laurie',
#                u'lastname': u'Breland',
#                u'phonenumber': u'087-853-4995',
#                u'zipcode': u'44359'},
#               {u'color': u'red',
#                u'firstname': u'Englebert G.',
#                u'lastname': u'Humperdink',
#                u'phonenumber': u'839-014-8051',
#                u'zipcode': u'36410'},
#               {u'color': u'pink',
#                u'firstname': u'Beata',
#                u'lastname': u'Dhillon',
#                u'phonenumber': u'843-661-4252',
#                u'zipcode': u'90022'},
#               {u'color': u'blue',
#                u'firstname': u'Magan',
#                u'lastname': u'Leedy',
#                u'phonenumber': u'896-391-7308',
#                u'zipcode': u'48680'},
#               {u'color': u'pink',
#                u'firstname': u'Shanika',
#                u'lastname': u'Dodd',
#                u'phonenumber': u'940-761-0886',
#                u'zipcode': u'82733'},
#               {u'color': u'pink',
#                u'firstname': u'Hung',
#                u'lastname': u'Moxley',
#                u'phonenumber': u'667-132-9000',
#                u'zipcode': u'93381'},
#               {u'color': u'aqua marine',
#                u'firstname': u'Andy',
#                u'lastname': u'Patnaude',
#                u'phonenumber': u'612-712-8471',
#                u'zipcode': u'29198'},
#               {u'color': u'blue',
#                u'firstname': u'Maurita',
#                u'lastname': u'Awong',
#                u'phonenumber': u'061-937-1243',
#                u'zipcode': u'15726'},
#               {u'color': u'red',
#                u'firstname': u'Marita',
#                u'lastname': u'Haugland',
#                u'phonenumber': u'034-614-7966',
#                u'zipcode': u'21231'},
#               {u'color': u'blue',
#                u'firstname': u'Kristeen',
#                u'lastname': u'Swearingen',
#                u'phonenumber': u'238-440-6451',
#                u'zipcode': u'60460'},
#               {u'color': u'blue',
#                u'firstname': u'Sabina',
#                u'lastname': u'Saltsman',
#                u'phonenumber': u'577-767-9995',
#                u'zipcode': u'81360'},
#               {u'color': u'yellow',
#                u'firstname': u'Armand',
#                u'lastname': u'Davis',
#                u'phonenumber': u'240-736-4719',
#                u'zipcode': u'64320'},
#               {u'color': u'red',
#                u'firstname': u'Kerri',
#                u'lastname': u'Chandler',
#                u'phonenumber': u'818-246-5061',
#                u'zipcode': u'32868'},
#               {u'color': u'pink',
#                u'firstname': u'Shela',
#                u'lastname': u'Mona',
#                u'phonenumber': u'986-283-6066',
#                u'zipcode': u'11198'},
#               {u'color': u'gray',
#                u'firstname': u'Prince',
#                u'lastname': u'Gabler',
#                u'phonenumber': u'645-200-7094',
#                u'zipcode': u'08291'},
#               {u'color': u'blue',
#                u'firstname': u'Earlene',
#                u'lastname': u'Merryman',
#                u'phonenumber': u'305-987-8362',
#                u'zipcode': u'86258'},
#               {u'color': u'red',
#                u'firstname': u'Theodora',
#                u'lastname': u'Whipkey',
#                u'phonenumber': u'808-633-1734',
#                u'zipcode': u'54450'},
#               {u'color': u'yellow',
#                u'firstname': u'Kelsi',
#                u'lastname': u'Butterfield',
#                u'phonenumber': u'967-196-4953',
#                u'zipcode': u'05644'},
#               {u'color': u'gray',
#                u'firstname': u'Fatimah',
#                u'lastname': u'Mccaster',
#                u'phonenumber': u'854-345-7518',
#                u'zipcode': u'57693'},
#               {u'color': u'aqua marine',
#                u'firstname': u'Mirian',
#                u'lastname': u'Hankey',
#                u'phonenumber': u'180-739-1295',
#                u'zipcode': u'22172'},
#               {u'color': u'gray',
#                u'firstname': u'Reinaldo',
#                u'lastname': u'Vandermeer',
#                u'phonenumber': u'751-665-5618',
#                u'zipcode': u'76589'},
#               {u'color': u'green',
#                u'firstname': u'Theo',
#                u'lastname': u'Parrish',
#                u'phonenumber': u'423-334-3136',
#                u'zipcode': u'60128'},
#               {u'color': u'gray',
#                u'firstname': u'Mazie',
#                u'lastname': u'Chavis',
#                u'phonenumber': u'218-097-2208',
#                u'zipcode': u'48843'},
#               {u'color': u'red',
#                u'firstname': u'Kent',
#                u'lastname': u'Demming',
#                u'phonenumber': u'622-720-0550',
#                u'zipcode': u'37820'},
#               {u'color': u'aqua marine',
#                u'firstname': u'Len',
#                u'lastname': u'Pollack',
#                u'phonenumber': u'642-573-6473',
#                u'zipcode': u'29868'},
#               {u'color': u'green',
#                u'firstname': u'Myrtice',
#                u'lastname': u'Ferro',
#                u'phonenumber': u'568-821-3874',
#                u'zipcode': u'95836'},
#               {u'color': u'pink',
#                u'firstname': u'Isabell',
#                u'lastname': u'Mcclusky',
#                u'phonenumber': u'676-545-7599',
#                u'zipcode': u'12312'},
#               {u'color': u'aqua marine',
#                u'firstname': u'Margarete',
#                u'lastname': u'Stickle',
#                u'phonenumber': u'805-612-0845',
#                u'zipcode': u'92493'},
#               {u'color': u'red',
#                u'firstname': u'Clarinda',
#                u'lastname': u'Cadena',
#                u'phonenumber': u'666-621-7485',
#                u'zipcode': u'09517'},
#               {u'color': u'pink',
#                u'firstname': u'Bernie',
#                u'lastname': u'Mallette',
#                u'phonenumber': u'859-924-2843',
#                u'zipcode': u'17300'},
#               {u'color': u'blue',
#                u'firstname': u'Hyo',
#                u'lastname': u'Ballentine',
#                u'phonenumber': u'182-424-5300',
#                u'zipcode': u'21351'},
#               {u'color': u'green',
#                u'firstname': u'Azzie',
#                u'lastname': u'Zabriskie',
#                u'phonenumber': u'110-574-1904',
#                u'zipcode': u'94339'},
#               {u'color': u'yellow',
#                u'firstname': u'Jacques',
#                u'lastname': u'Renault',
#                u'phonenumber': u'157-348-8325',
#                u'zipcode': u'00328'},
#               {u'color': u'blue',
#                u'firstname': u'Magaly',
#                u'lastname': u'Gregor',
#                u'phonenumber': u'698-513-7428',
#                u'zipcode': u'86286'},
#               {u'color': u'pink',
#                u'firstname': u'France',
#                u'lastname': u'Schuetz',
#                u'phonenumber': u'732-729-4104',
#                u'zipcode': u'09893'},
#               {u'color': u'blue',
#                u'firstname': u'Darline',
#                u'lastname': u'Barbeau',
#                u'phonenumber': u'260-619-7450',
#                u'zipcode': u'11027'},
#               {u'color': u'pink',
#                u'firstname': u'Darcie',
#                u'lastname': u'Phoenix',
#                u'phonenumber': u'854-910-7619',
#                u'zipcode': u'55806'},
#               {u'color': u'blue',
#                u'firstname': u'Justin',
#                u'lastname': u'Miller',
#                u'phonenumber': u'657-743-7189',
#                u'zipcode': u'58979'}],
#  u'errors': [0, 5, 7, 15, 16, 29, 37, 38, 41, 43, 44, 45, 47, 48, 56, 57, 62]}

# %%
output = output_schema.dumps(data, sort_keys=True, indent=4).data
print output
# Out:
# {
#     "entries": [
#         {
#             "color": "aqua marine",
#             "firstname": "Ria",
#             "lastname": "Tillotson",
#             "phonenumber": "196-910-5548",
#             "zipcode": "97671"
#         },
#         {
#             "color": "blue",
#             "firstname": "Annalee",
#             "lastname": "Loftis",
#             "phonenumber": "905-329-2054",
#             "zipcode": "97296"
#         },
#         {
#             "color": "gray",
#             "firstname": "James",
#             "lastname": "Johnston",
#             "phonenumber": "628-102-3672",
#             "zipcode": "38410"
#         },
#         {
#             "color": "yellow",
#             "firstname": "Quinton",
#             "lastname": "Liptak",
#             "phonenumber": "653-889-7235",
#             "zipcode": "70703"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "George",
#             "lastname": "Won",
#             "phonenumber": "488-084-5794",
#             "zipcode": "97148"
#         },
#         {
#             "color": "pink",
#             "firstname": "Gladis",
#             "lastname": "Tubb",
#             "phonenumber": "454-934-6454",
#             "zipcode": "73149"
#         },
#         {
#             "color": "pink",
#             "firstname": "Aura",
#             "lastname": "Eilers",
#             "phonenumber": "489-634-9504",
#             "zipcode": "39358"
#         },
#         {
#             "color": "red",
#             "firstname": "Blair",
#             "lastname": "Clary",
#             "phonenumber": "463-118-2451",
#             "zipcode": "07256"
#         },
#         {
#             "color": "pink",
#             "firstname": "Robert",
#             "lastname": "Hood",
#             "phonenumber": "054-813-6030",
#             "zipcode": "47784"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "Laurie",
#             "lastname": "Breland",
#             "phonenumber": "087-853-4995",
#             "zipcode": "44359"
#         },
#         {
#             "color": "red",
#             "firstname": "Englebert G.",
#             "lastname": "Humperdink",
#             "phonenumber": "839-014-8051",
#             "zipcode": "36410"
#         },
#         {
#             "color": "pink",
#             "firstname": "Beata",
#             "lastname": "Dhillon",
#             "phonenumber": "843-661-4252",
#             "zipcode": "90022"
#         },
#         {
#             "color": "blue",
#             "firstname": "Magan",
#             "lastname": "Leedy",
#             "phonenumber": "896-391-7308",
#             "zipcode": "48680"
#         },
#         {
#             "color": "pink",
#             "firstname": "Shanika",
#             "lastname": "Dodd",
#             "phonenumber": "940-761-0886",
#             "zipcode": "82733"
#         },
#         {
#             "color": "pink",
#             "firstname": "Hung",
#             "lastname": "Moxley",
#             "phonenumber": "667-132-9000",
#             "zipcode": "93381"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "Andy",
#             "lastname": "Patnaude",
#             "phonenumber": "612-712-8471",
#             "zipcode": "29198"
#         },
#         {
#             "color": "blue",
#             "firstname": "Maurita",
#             "lastname": "Awong",
#             "phonenumber": "061-937-1243",
#             "zipcode": "15726"
#         },
#         {
#             "color": "red",
#             "firstname": "Marita",
#             "lastname": "Haugland",
#             "phonenumber": "034-614-7966",
#             "zipcode": "21231"
#         },
#         {
#             "color": "blue",
#             "firstname": "Kristeen",
#             "lastname": "Swearingen",
#             "phonenumber": "238-440-6451",
#             "zipcode": "60460"
#         },
#         {
#             "color": "blue",
#             "firstname": "Sabina",
#             "lastname": "Saltsman",
#             "phonenumber": "577-767-9995",
#             "zipcode": "81360"
#         },
#         {
#             "color": "yellow",
#             "firstname": "Armand",
#             "lastname": "Davis",
#             "phonenumber": "240-736-4719",
#             "zipcode": "64320"
#         },
#         {
#             "color": "red",
#             "firstname": "Kerri",
#             "lastname": "Chandler",
#             "phonenumber": "818-246-5061",
#             "zipcode": "32868"
#         },
#         {
#             "color": "pink",
#             "firstname": "Shela",
#             "lastname": "Mona",
#             "phonenumber": "986-283-6066",
#             "zipcode": "11198"
#         },
#         {
#             "color": "gray",
#             "firstname": "Prince",
#             "lastname": "Gabler",
#             "phonenumber": "645-200-7094",
#             "zipcode": "08291"
#         },
#         {
#             "color": "blue",
#             "firstname": "Earlene",
#             "lastname": "Merryman",
#             "phonenumber": "305-987-8362",
#             "zipcode": "86258"
#         },
#         {
#             "color": "red",
#             "firstname": "Theodora",
#             "lastname": "Whipkey",
#             "phonenumber": "808-633-1734",
#             "zipcode": "54450"
#         },
#         {
#             "color": "yellow",
#             "firstname": "Kelsi",
#             "lastname": "Butterfield",
#             "phonenumber": "967-196-4953",
#             "zipcode": "05644"
#         },
#         {
#             "color": "gray",
#             "firstname": "Fatimah",
#             "lastname": "Mccaster",
#             "phonenumber": "854-345-7518",
#             "zipcode": "57693"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "Mirian",
#             "lastname": "Hankey",
#             "phonenumber": "180-739-1295",
#             "zipcode": "22172"
#         },
#         {
#             "color": "gray",
#             "firstname": "Reinaldo",
#             "lastname": "Vandermeer",
#             "phonenumber": "751-665-5618",
#             "zipcode": "76589"
#         },
#         {
#             "color": "green",
#             "firstname": "Theo",
#             "lastname": "Parrish",
#             "phonenumber": "423-334-3136",
#             "zipcode": "60128"
#         },
#         {
#             "color": "gray",
#             "firstname": "Mazie",
#             "lastname": "Chavis",
#             "phonenumber": "218-097-2208",
#             "zipcode": "48843"
#         },
#         {
#             "color": "red",
#             "firstname": "Kent",
#             "lastname": "Demming",
#             "phonenumber": "622-720-0550",
#             "zipcode": "37820"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "Len",
#             "lastname": "Pollack",
#             "phonenumber": "642-573-6473",
#             "zipcode": "29868"
#         },
#         {
#             "color": "green",
#             "firstname": "Myrtice",
#             "lastname": "Ferro",
#             "phonenumber": "568-821-3874",
#             "zipcode": "95836"
#         },
#         {
#             "color": "pink",
#             "firstname": "Isabell",
#             "lastname": "Mcclusky",
#             "phonenumber": "676-545-7599",
#             "zipcode": "12312"
#         },
#         {
#             "color": "aqua marine",
#             "firstname": "Margarete",
#             "lastname": "Stickle",
#             "phonenumber": "805-612-0845",
#             "zipcode": "92493"
#         },
#         {
#             "color": "red",
#             "firstname": "Clarinda",
#             "lastname": "Cadena",
#             "phonenumber": "666-621-7485",
#             "zipcode": "09517"
#         },
#         {
#             "color": "pink",
#             "firstname": "Bernie",
#             "lastname": "Mallette",
#             "phonenumber": "859-924-2843",
#             "zipcode": "17300"
#         },
#         {
#             "color": "blue",
#             "firstname": "Hyo",
#             "lastname": "Ballentine",
#             "phonenumber": "182-424-5300",
#             "zipcode": "21351"
#         },
#         {
#             "color": "green",
#             "firstname": "Azzie",
#             "lastname": "Zabriskie",
#             "phonenumber": "110-574-1904",
#             "zipcode": "94339"
#         },
#         {
#             "color": "yellow",
#             "firstname": "Jacques",
#             "lastname": "Renault",
#             "phonenumber": "157-348-8325",
#             "zipcode": "00328"
#         },
#         {
#             "color": "blue",
#             "firstname": "Magaly",
#             "lastname": "Gregor",
#             "phonenumber": "698-513-7428",
#             "zipcode": "86286"
#         },
#         {
#             "color": "pink",
#             "firstname": "France",
#             "lastname": "Schuetz",
#             "phonenumber": "732-729-4104",
#             "zipcode": "09893"
#         },
#         {
#             "color": "blue",
#             "firstname": "Darline",
#             "lastname": "Barbeau",
#             "phonenumber": "260-619-7450",
#             "zipcode": "11027"
#         },
#         {
#             "color": "pink",
#             "firstname": "Darcie",
#             "lastname": "Phoenix",
#             "phonenumber": "854-910-7619",
#             "zipcode": "55806"
#         },
#         {
#             "color": "blue",
#             "firstname": "Justin",
#             "lastname": "Miller",
#             "phonenumber": "657-743-7189",
#             "zipcode": "58979"
#         }
#     ],
#     "errors": [
#         0,
#         5,
#         7,
#         15,
#         16,
#         29,
#         37,
#         38,
#         41,
#         43,
#         44,
#         45,
#         47,
#         48,
#         56,
#         57,
#         62
#     ]
# }
